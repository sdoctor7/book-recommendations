# %%
import numpy as np
import pandas as pd

# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)

# %%
def read_data(path):
    df = pd.read_csv(path)
#    df.columns = ['USER', 'ITEM', 'RATING', 'TIMESTAMP']
    return df

# %%
ratings = read_data('ratings.csv')

# %%
ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
ratings['rating'].value_counts()
# Out:
# 4    2139018
# 5    1983093
# 3    1370916
# 2     359257
# 1     124195
# Name: rating, dtype: int64

# %%
print(len(ratings.user_id.unique()), len(ratings.book_id.unique()))
# Out:
# 53424 10000

# %%
ratings_10k = ratings.sample(frac = 0.001)

# %%
print(len(ratings_10k.user_id.unique()), len(ratings_10k.book_id.unique()))
# Out:
# 5646 3098

# %%
len(ratings_10k)/(len(ratings_10k.user_id.unique())*len(ratings_10k.book_id.unique()))
# Out:
# 0.0003416554096468943

# %%
len(ratings)/(len(ratings.user_id.unique())*len(ratings.book_id.unique()))
# Out:
# 0.011186880428271938

# %%
user_counts = pd.DataFrame(ratings.user_id.value_counts())

# %%
user_counts.user_id.quantile([0.3, 0.8])
# Out:
# 0.3     99.0
# 0.8    133.0
# Name: user_id, dtype: float64

# %%
user_counts.head()
# Out:
#        user_id
# 30944      200
# 12874      200
# 52036      199
# 28158      199
# 12381      199

# %%
users = list(user_counts[user_counts['user_id']>100].index)

# %%
top_users = users[0:10000]

# %%
# Function to pick a new dataset with the X most prolific reviewers and Y most reviewed books
#adam edited
def pick_users_books(df, num_users, num_books):
    user_counts = pd.DataFrame(df.user_id.value_counts()).sort_values('user_id', ascending=False)
    top_10K_users = list(user_counts[0:num_users].index)
    user_filtered_df = df[df.user_id.isin(top_10K_users)]
    filtered_book_counts = pd.DataFrame(user_filtered_df.book_id.value_counts()).sort_values('book_id', ascending = False)
    top_100_filtered_books = list(filtered_book_counts[0:num_books].index)
    filtered_df = user_filtered_df[user_filtered_df.book_id.isin(top_100_filtered_books)]
    print("New dataframe has {} users, {} items, and a sparsity of {}".format(len(filtered_df.user_id.unique()),len(filtered_df.book_id.unique()),len(filtered_df)/(len(filtered_df.user_id.unique())*len(filtered_df.book_id.unique()))))
    train, test = train_test_split(filtered_df, test_size = 0.2, random_state=42)
    return train, test
    
def get_all_subsets(df):
    train_500_20, test_500_20 = pick_users_books(df, 500, 20)
    train_2000_50, test_2000_50 = pick_users_books(df, 2000, 50)
    train_10000_100, test_10000_100 = pick_users_books(df, 10000, 100)
    return train_500_20, test_500_20, train_2000_50, test_2000_50, train_10000_100, test_10000_100

# %%
train_500_20, test_500_20, train_2000_50, test_2000_50, train_10000_100, test_10000_100 = get_all_subsets(ratings)
# Out:
# New dataframe has 487 users, 20 items, and a sparsity of 0.442607802875
# New dataframe has 1981 users, 50 items, and a sparsity of 0.374558303887
# New dataframe has 9980 users, 100 items, and a sparsity of 0.271965931864

# %%
new_ratings = pick_users_books(ratings, 2000, 30)
# Out:
# New dataframe has 1972 users, 30 items, and a sparsity of 0

# %%
from sklearn.model_selection import train_test_split

# %%
import surprise

# %%
import random
random.seed(42)

# %%
def grid_search_data(df, algorithm, parameter_grid, metrics):
    reader = surprise.Reader(rating_scale=(1,5))
    data = surprise.Dataset.load_from_df(df, reader)
    data.split(n_folds = 3)
    grid_search = surprise.GridSearch(algorithm, parameter_grid, measures = metrics)
    grid_search.evaluate(data)
    results_df = pd.DataFrame.from_dict(grid_search.cv_results)
    return results_df

# %%
# TESTING WITH THE WHOLE 10k USERS DATA JUST USER-BASED AND JUST RMSE
algorithm1 = surprise.prediction_algorithms.knns.KNNWithMeans
param_grid = {'k': [10, 50, 200], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 3], 'user_based': [True]}}
KNN_means_results_full = grid_search_data(train_10000_100, algorithm1, param_grid, ['RMSE'])
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}]
# ------------
# Parameters combination 1 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9278
# ------------
# ------------
# Parameters combination 2 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8988
# ------------
# ------------
# Parameters combination 3 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8892
# ------------
# ------------
# Parameters combination 4 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9109
# ------------
# ------------
# Parameters combination 5 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8836
# ------------
# ------------
# Parameters combination 6 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8820
# ------------
# ------------
# Parameters combination 7 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9265
# ------------
# ------------
# Parameters combination 8 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8968
# ------------
# ------------
# Parameters combination 9 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8863
# ------------
# ------------
# Parameters combination 10 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9183
# ------------
# ------------
# Parameters combination 11 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8887
# ------------
# ------------
# Parameters combination 12 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8831
# ------------
# ------------
# Parameters combination 13 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8917
# ------------
# ------------
# Parameters combination 14 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8675
# ------------
# ------------
# Parameters combination 15 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8699
# ------------
# ------------
# Parameters combination 16 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8922
# ------------
# ------------
# Parameters combination 17 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8685
# ------------
# ------------
# Parameters combination 18 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8709
# ------------

# %%
KNN_means_results_full_df_user = convert_grid_results(KNN_means_results_full)
KNN_means_results_full_df_user
# Out:
#         RMSE  min_support              name  user_based
# 0   0.927773            1               msd        True
# 1   0.898820            1               msd        True
# 2   0.889167            1               msd        True
# 3   0.910945            3               msd        True
# 4   0.883578            3               msd        True
# 5   0.881968            3               msd        True
# 6   0.926526            1           pearson        True
# 7   0.896781            1           pearson        True
# 8   0.886311            1           pearson        True
# 9   0.918250            3           pearson        True
# 10  0.888704            3           pearson        True
# 11  0.883124            3           pearson        True
# 12  0.891678            1  pearson_baseline        True
# 13  0.867488            1  pearson_baseline        True
# 14  0.869896            1  pearson_baseline        True
# 15  0.892238            3  pearson_baseline        True
# 16  0.868473            3  pearson_baseline        True
# 17  0.870904            3  pearson_baseline        True

# %%
algorithm1 = surprise.prediction_algorithms.knns.KNNWithMeans
param_grid = {'k': [10, 50, 200], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 3], 'user_based': [False]}}
KNN_means_results_full_items = grid_search_data(train_10000_100, algorithm1, param_grid, ['RMSE'])
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}]
# ------------
# Parameters combination 1 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8783
# ------------
# ------------
# Parameters combination 2 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8882
# ------------
# ------------
# Parameters combination 3 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8882
# ------------
# ------------
# Parameters combination 4 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8783
# ------------
# ------------
# Parameters combination 5 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8882
# ------------
# ------------
# Parameters combination 6 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'msd', u'user_based': False}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8882
# ------------
# ------------
# Parameters combination 7 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8651
# ------------
# ------------
# Parameters combination 8 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8686
# ------------
# ------------
# Parameters combination 9 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8686
# ------------
# ------------
# Parameters combination 10 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8651
# ------------
# ------------
# Parameters combination 11 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8686
# ------------
# ------------
# Parameters combination 12 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson', u'user_based': False}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8686
# ------------
# ------------
# Parameters combination 13 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8728
# ------------
# ------------
# Parameters combination 14 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8721
# ------------
# ------------
# Parameters combination 15 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8721
# ------------
# ------------
# Parameters combination 16 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8728
# ------------
# ------------
# Parameters combination 17 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8721
# ------------
# ------------
# Parameters combination 18 of 18
# params:  {u'sim_options': {u'min_support': 3, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8721
# ------------

# %%
KNN_means_results_full_df_items = convert_grid_results(KNN_means_results_full_items)
KNN_means_results_full_df_items
# Out:
#         RMSE  min_support              name  user_based
# 0   0.878344            1               msd       False
# 1   0.888194            1               msd       False
# 2   0.888193            1               msd       False
# 3   0.878344            3               msd       False
# 4   0.888194            3               msd       False
# 5   0.888193            3               msd       False
# 6   0.865087            1           pearson       False
# 7   0.868604            1           pearson       False
# 8   0.868604            1           pearson       False
# 9   0.865087            3           pearson       False
# 10  0.868604            3           pearson       False
# 11  0.868604            3           pearson       False
# 12  0.872763            1  pearson_baseline       False
# 13  0.872147            1  pearson_baseline       False
# 14  0.872147            1  pearson_baseline       False
# 15  0.872763            3  pearson_baseline       False
# 16  0.872147            3  pearson_baseline       False
# 17  0.872147            3  pearson_baseline       False

# %%
KNN_means_results_full_df = pd.concat([KNN_means_results_full_df_user, KNN_means_results_full_df_items], ignore_index=True)
KNN_means_results_full_df.iloc[KNN_means_results_full_df['RMSE'].idxmin()]
# Out:
# RMSE           0.865087
# min_support           1
# name            pearson
# user_based        False
# Name: 24, dtype: object

# %%
KNN_means_results_full_df.to_csv('KNN_means_grid_results.csv')

# %%
KNN_basic_results_full = convert_grid_results(KNN_basic_results_full)

# %%
KNN_basic_results_full
# Out:
#          MAE      RMSE    k  min_support              name  user_based
# 0   0.724231  0.940356   10            1               msd        True
# 1   0.699783  0.906091   50            1               msd        True
# 2   0.720742  0.918262  200            1               msd        True
# 3   0.756389  0.987760   10            5               msd        True
# 4   0.769269  0.991301   50            5               msd        True
# 5   0.776959  0.997430  200            5               msd        True
# 6   0.790849  0.991834   10            1           pearson        True
# 7   0.768264  0.960135   50            1           pearson        True
# 8   0.768413  0.959607  200            1           pearson        True
# 9   0.798235  1.027444   10            5           pearson        True
# 10  0.795499  1.020266   50            5           pearson        True
# 11  0.795478  1.020216  200            5           pearson        True
# 12  0.725071  0.934735   10            1  pearson_baseline        True
# 13  0.710641  0.910776   50            1  pearson_baseline        True
# 14  0.716360  0.914220  200            1  pearson_baseline        True
# 15  0.770019  1.005533   10            5  pearson_baseline        True
# 16  0.767919  0.999164   50            5  pearson_baseline        True
# 17  0.768113  0.999213  200            5  pearson_baseline        True
# 18  0.719556  0.959266   10            1               msd       False
# 19  0.722351  0.961018   50            1               msd       False
# 20  0.722351  0.961018  200            1               msd       False
# 21  0.719556  0.959266   10            5               msd       False
# 22  0.722351  0.961018   50            5               msd       False
# 23  0.722351  0.961018  200            5               msd       False
# 24  0.708840  0.955588   10            1           pearson       False
# 25  0.709233  0.955788   50            1           pearson       False
# 26  0.709233  0.955788  200            1           pearson       False
# 27  0.708840  0.955588   10            5           pearson       False
# 28  0.709233  0.955788   50            5           pearson       False
# 29  0.709233  0.955788  200            5           pearson       False
# 30  0.701645  0.984793   10            1  pearson_baseline       False
# 31  0.701648  0.984778   50            1  pearson_baseline       False
# 32  0.701648  0.984778  200            1  pearson_baseline       False
# 33  0.701645  0.984793   10            5  pearson_baseline       False
# 34  0.701648  0.984778   50            5  pearson_baseline       False
# 35  0.701648  0.984778  200            5  pearson_baseline       False

# %%
algorithm = surprise.prediction_algorithms.knns.KNNWithMeans
param_grid = {'k': [10, 50, 200], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 5], 'user_based': [True, False]}}
KNN_with_means_full = convert_grid_results(grid_search_data(train_10000_100, algorithm, param_grid, ['RMSE', 'MAE']))
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}]
# ------------
# Parameters combination 1 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9220
# Mean MAE : 0.7072
# ------------
# ------------
# Parameters combination 2 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8952
# Mean MAE : 0.6868
# ------------
# ------------
# Parameters combination 3 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8913
# Mean MAE : 0.6826
# ------------
# ------------
# Parameters combination 4 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9092
# Mean MAE : 0.6898
# ------------
# ------------
# Parameters combination 5 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9031
# Mean MAE : 0.6858
# ------------
# ------------
# Parameters combination 6 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9100
# Mean MAE : 0.6916
# ------------
# ------------
# Parameters combination 7 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9191
# Mean MAE : 0.6850
# ------------
# ------------
# Parameters combination 8 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8939
# Mean MAE : 0.6651
# ------------
# ------------
# Parameters combination 9 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8916
# Mean MAE : 0.6642
# ------------
# ------------
# Parameters combination 10 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9197
# Mean MAE : 0.6848
# ------------
# ------------
# Parameters combination 11 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9089
# Mean MAE : 0.6773
# ------------
# ------------
# Parameters combination 12 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9100
# Mean MAE : 0.6792
# ------------
# ------------
# Parameters combination 13 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8937
# Mean MAE : 0.6753
# ------------
# ------------
# Parameters combination 14 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8747
# Mean MAE : 0.6636
# ------------
# ------------
# Parameters combination 15 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8780
# Mean MAE : 0.6671
# ------------
# ------------
# Parameters combination 16 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9149
# Mean MAE : 0.6896
# ------------
# ------------
# Parameters combination 17 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9034
# Mean MAE : 0.6814
# ------------
# ------------
# Parameters combination 18 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9041
# Mean MAE : 0.6823
# ------------
# ------------
# Parameters combination 19 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8839
# Mean MAE : 0.6686
# ------------
# ------------
# Parameters combination 20 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8862
# Mean MAE : 0.6720
# ------------
# ------------
# Parameters combination 21 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8862
# Mean MAE : 0.6720
# ------------
# ------------
# Parameters combination 22 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8839
# Mean MAE : 0.6686
# ------------
# ------------
# Parameters combination 23 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8862
# Mean MAE : 0.6720
# ------------
# ------------
# Parameters combination 24 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8862
# Mean MAE : 0.6720
# ------------
# ------------
# Parameters combination 25 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8678
# Mean MAE : 0.6477
# ------------
# ------------
# Parameters combination 26 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8683
# Mean MAE : 0.6490
# ------------
# ------------
# Parameters combination 27 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8683
# Mean MAE : 0.6490
# ------------
# ------------
# Parameters combination 28 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8678
# Mean MAE : 0.6477
# ------------
# ------------
# Parameters combination 29 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8683
# Mean MAE : 0.6490
# ------------
# ------------
# Parameters combination 30 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8683
# Mean MAE : 0.6490
# ------------
# ------------
# Parameters combination 31 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------
# ------------
# Parameters combination 32 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------
# ------------
# Parameters combination 33 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------
# ------------
# Parameters combination 34 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------
# ------------
# Parameters combination 35 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------
# ------------
# Parameters combination 36 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8903
# Mean MAE : 0.6438
# ------------

# %%
KNN_with_means_full
# Out:
#          MAE      RMSE    k  min_support              name  user_based
# 0   0.707187  0.922010   10            1               msd        True
# 1   0.686809  0.895225   50            1               msd        True
# 2   0.682618  0.891339  200            1               msd        True
# 3   0.689805  0.909207   10            5               msd        True
# 4   0.685781  0.903113   50            5               msd        True
# 5   0.691583  0.909969  200            5               msd        True
# 6   0.684972  0.919079   10            1           pearson        True
# 7   0.665134  0.893930   50            1           pearson        True
# 8   0.664192  0.891576  200            1           pearson        True
# 9   0.684776  0.919688   10            5           pearson        True
# 10  0.677265  0.908874   50            5           pearson        True
# 11  0.679153  0.909982  200            5           pearson        True
# 12  0.675257  0.893660   10            1  pearson_baseline        True
# 13  0.663609  0.874660   50            1  pearson_baseline        True
# 14  0.667137  0.878042  200            1  pearson_baseline        True
# 15  0.689593  0.914896   10            5  pearson_baseline        True
# 16  0.681449  0.903437   50            5  pearson_baseline        True
# 17  0.682294  0.904098  200            5  pearson_baseline        True
# 18  0.668614  0.883864   10            1               msd       False
# 19  0.672047  0.886197   50            1               msd       False
# 20  0.672047  0.886197  200            1               msd       False
# 21  0.668614  0.883864   10            5               msd       False
# 22  0.672047  0.886197   50            5               msd       False
# 23  0.672047  0.886197  200            5               msd       False
# 24  0.647731  0.867826   10            1           pearson       False
# 25  0.648962  0.868336   50            1           pearson       False
# 26  0.648962  0.868336  200            1           pearson       False
# 27  0.647731  0.867826   10            5           pearson       False
# 28  0.648962  0.868336   50            5           pearson       False
# 29  0.648962  0.868336  200            5           pearson       False
# 30  0.643801  0.890332   10            1  pearson_baseline       False
# 31  0.643751  0.890275   50            1  pearson_baseline       False
# 32  0.643751  0.890275  200            1  pearson_baseline       False
# 33  0.643801  0.890332   10            5  pearson_baseline       False
# 34  0.643751  0.890275   50            5  pearson_baseline       False
# 35  0.643751  0.890275  200            5  pearson_baseline       False

# %%
algorithm = surprise.prediction_algorithms.knns.KNNWithZScore
param_grid = {'k': [10, 50, 200], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 5], 'user_based': [True, False]}}
KNN_with_zscore_full = convert_grid_results(grid_search_data(train_10000_100, algorithm, param_grid, ['RMSE', 'MAE']))
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': False}, u'k': 200}]
# ------------
# Parameters combination 1 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9334
# Mean MAE : 0.7136
# ------------
# ------------
# Parameters combination 2 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8996
# Mean MAE : 0.6902
# ------------
# ------------
# Parameters combination 3 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8941
# Mean MAE : 0.6842
# ------------
# ------------
# Parameters combination 4 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9218
# Mean MAE : 0.6931
# ------------
# ------------
# Parameters combination 5 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9064
# Mean MAE : 0.6846
# ------------
# ------------
# Parameters combination 6 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 200}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9134
# Mean MAE : 0.6909
# ------------
# ------------
# Parameters combination 7 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9211
# Mean MAE : 0.6812
# ------------
# ------------
# Parameters combination 8 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8948
# Mean MAE : 0.6638
# ------------
# ------------
# Parameters combination 9 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8937
# Mean MAE : 0.6646
# ------------
# ------------
# Parameters combination 10 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9171
# Mean MAE : 0.6789
# ------------
# ------------
# Parameters combination 11 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9068
# Mean MAE : 0.6735
# ------------
# ------------
# Parameters combination 12 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 200}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9077
# Mean MAE : 0.6751
# ------------
# ------------
# Parameters combination 13 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8984
# Mean MAE : 0.6759
# ------------
# ------------
# Parameters combination 14 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8787
# Mean MAE : 0.6653
# ------------
# ------------
# Parameters combination 15 of 36
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 200}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.8817
# Mean MAE : 0.6693
# ------------
# ------------
# Parameters combination 16 of 36
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-be3a2dcf65c2> in <module>()
#       1 algorithm = surprise.prediction_algorithms.knns.KNNWithZScore
#       2 param_grid = {'k': [10, 50, 200], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 5], 'user_based': [True, False]}}
# ----> 3 KNN_with_zscore_full = convert_grid_results(grid_search_data(train_10000_100, algorithm, param_grid, ['RMSE', 'MAE']))
#
# <ipython-input-149-ffde36218a17> in grid_search_data(df, algorithm, parameter_grid, metrics)
#       4     data.split(n_folds = 5)
#       5     grid_search = surprise.GridSearch(algorithm, parameter_grid, measures = metrics)
# ----> 6     grid_search.evaluate(data)
#       7     results_df = pd.DataFrame.from_dict(grid_search.cv_results)
#       8     return results_df
#
# /Users/adamcoviensky/anaconda/lib/python2.7/site-packages/surprise/evaluate.pyc in evaluate(self, data)
#     204             evaluate_results = evaluate(algo_instance, data,
#     205                                         measures=self.measures,
# --> 206                                         verbose=(self.verbose == 2))
#     207
#     208             # measures as keys and folds average as values
#
# /Users/adamcoviensky/anaconda/lib/python2.7/site-packages/surprise/evaluate.pyc in evaluate(algo, data, measures, with_dump, dump_dir, verbose)
#      63
#      64         # train and test algorithm. Keep all rating predictions in a list
# ---> 65         algo.train(trainset)
#      66         predictions = algo.test(testset, verbose=(verbose == 2))
#      67
#
# /Users/adamcoviensky/anaconda/lib/python2.7/site-packages/surprise/prediction_algorithms/knns.pyc in train(self, trainset)
#     359             self.sigmas[x] = self.overall_sigma if sigma == 0.0 else sigma
#     360
# --> 361         self.sim = self.compute_similarities()
#     362
#     363     def estimate(self, u, i):
#
# /Users/adamcoviensky/anaconda/lib/python2.7/site-packages/surprise/prediction_algorithms/algo_base.pyc in compute_similarities(self)
#     230             print('Computing the {0} similarity matrix...'.format(name))
#     231             sim = construction_func[name](*args)
# --> 232             print('Done computing similarity matrix.')
#     233             return sim
#     234         except KeyError:
#
# /Users/adamcoviensky/anaconda/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     315
#     316             is_child = (not self._is_master_process())
# --> 317             self._buffer.write(string)
#     318             if is_child:
#     319                 # newlines imply flush in subprocesses
#
# ValueError: I/O operation on closed file

# %%
#Need to do results_df = pd.DataFrame.from_dict(grid_search.cv_results)
def convert_grid_results(df):
    my_dict = df.to_dict('list')
    min_support = []
    name = []
    user_based = []
    for x in range(len(my_dict['sim_options'])):
        y = my_dict['sim_options'][x]
        min_support.append(y['min_support'])
        name.append(y['name'])
        user_based.append(y['user_based'])
    del my_dict['params']
    del my_dict['scores']
    del my_dict['sim_options']
    my_dict['min_support'] = min_support
    my_dict['name'] = name
    my_dict['user_based'] = user_based
    my_df = pd.DataFrame.from_dict(my_dict)
    return my_df

# %%
reader = surprise.Reader(rating_scale=(1,5))

# %%
data = surprise.Dataset.load_from_df(train_ratings, reader)

# %%
pd.set_option('max_colwidth',100)
# Out:
#          MAE      RMSE   k  \
# 0   0.728966  0.941928  10
# 1   0.705857  0.913228  30
# 2   0.700889  0.907006  50
# 3   0.760297  0.991390  10
# 4   0.768088  0.992235  30
# 5   0.772903  0.995781  50
# 6   0.786464  0.987944  10
# 7   0.769580  0.963227  30
# 8   0.767056  0.959370  50
# 9   0.799204  1.025064  10
# 10  0.794760  1.018008  30
# 11  0.794510  1.017499  50
#
#                                                                                        params  \
# 0       {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# 1       {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}
# 2       {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# 3       {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# 4       {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}
# 5       {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# 6   {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 7   {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 8   {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# 9   {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 10  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 11  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
#
#                                                scores  \
# 0   {u'MAE': 0.728966240258, u'RMSE': 0.941928227992}
# 1   {u'MAE': 0.705857204072, u'RMSE': 0.913227742474}
# 2   {u'MAE': 0.700888543408, u'RMSE': 0.907005596044}
# 3    {u'MAE': 0.76029730044, u'RMSE': 0.991390484743}
# 4     {u'MAE': 0.76808817136, u'RMSE': 0.99223484538}
# 5   {u'MAE': 0.772902749466, u'RMSE': 0.995781050779}
# 6   {u'MAE': 0.786464391877, u'RMSE': 0.987943507298}
# 7     {u'MAE': 0.7695800303, u'RMSE': 0.963226815035}
# 8   {u'MAE': 0.767056114197, u'RMSE': 0.959369785109}
# 9    {u'MAE': 0.799204268804, u'RMSE': 1.02506390957}
# 10    {u'MAE': 0.794760128705, u'RMSE': 1.0180077013}
# 11   {u'MAE': 0.794510342592, u'RMSE': 1.01749855306}
#
#                                                       sim_options
# 0       {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 1       {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 2       {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 3       {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 4       {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 5       {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 6   {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 7   {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 8   {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 9   {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 10  {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 11  {u'min_support': 5, u'name': u'pearson', u'user_based': True}

# %%
param_grid_2 = {'k': [20, 50, 70, 100, 150], 'sim_options': {'name': ['msd', 'pearson_baseline'], 'min_support': [1], 'user_based': [True]}}

# %%
grid_search_2 = surprise.GridSearch(algo, param_grid_2, measures = ['RMSE', 'MAE'])
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 20}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 70}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 100}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 150}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 20}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 70}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 100}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 150}]

# %%
grid_search_2.evaluate(data)
# Out:
# ------------
# Parameters combination 1 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 20}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9208
# Mean MAE : 0.7128
# ------------
# ------------
# Parameters combination 2 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9070
# Mean MAE : 0.7009
# ------------
# ------------
# Parameters combination 3 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 70}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9050
# Mean MAE : 0.6998
# ------------
# ------------
# Parameters combination 4 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 100}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9058
# Mean MAE : 0.7020
# ------------
# ------------
# Parameters combination 5 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 150}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9116
# Mean MAE : 0.7111
# ------------
# ------------
# Parameters combination 6 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 20}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9169
# Mean MAE : 0.7144
# ------------
# ------------
# Parameters combination 7 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9111
# Mean MAE : 0.7115
# ------------
# ------------
# Parameters combination 8 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 70}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9117
# Mean MAE : 0.7124
# ------------
# ------------
# Parameters combination 9 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 100}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9133
# Mean MAE : 0.7143
# ------------
# ------------
# Parameters combination 10 of 10
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 150}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9148
# Mean MAE : 0.7166
# ------------

# %%
results_df2 = pd.DataFrame.from_dict(grid_search_2.cv_results)
results_df2
# Out:
#         MAE      RMSE    k  \
# 0  0.712761  0.920839   20
# 1  0.700889  0.907006   50
# 2  0.699758  0.904974   70
# 3  0.702028  0.905823  100
# 4  0.711136  0.911573  150
# 5  0.714442  0.916862   20
# 6  0.711494  0.911051   50
# 7  0.712436  0.911733   70
# 8  0.714273  0.913330  100
# 9  0.716635  0.914807  150
#
#                                                                                                 params  \
# 0                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 20}
# 1                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# 2                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 70}
# 3               {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 100}
# 4               {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 150}
# 5   {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 20}
# 6   {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# 7   {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 70}
# 8  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 100}
# 9  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 150}
#
#                                               scores  \
# 0   {u'MAE': 0.712761113634, u'RMSE': 0.92083898771}
# 1  {u'MAE': 0.700888543408, u'RMSE': 0.907005596044}
# 2  {u'MAE': 0.699757982434, u'RMSE': 0.904974072278}
# 3  {u'MAE': 0.702028176043, u'RMSE': 0.905822929171}
# 4  {u'MAE': 0.711136465362, u'RMSE': 0.911573075844}
# 5  {u'MAE': 0.714441781207, u'RMSE': 0.916861587753}
# 6  {u'MAE': 0.711493932251, u'RMSE': 0.911051465878}
# 7   {u'MAE': 0.71243623182, u'RMSE': 0.911733370374}
# 8  {u'MAE': 0.714273429679, u'RMSE': 0.913330466913}
# 9  {u'MAE': 0.716634713719, u'RMSE': 0.914806540231}
#
#                                                               sim_options
# 0               {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 1               {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 2               {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 3               {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 4               {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 5  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 6  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 7  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 8  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 9  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}

# %%
algo = surprise.prediction_algorithms.knns.KNNWithZScore
param_grid = {'k': [10, 30, 50], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 5], 'user_based': [True]}}
grid_search_knn_z = surprise.GridSearch(algo, param_grid, measures=['MAE', 'RMSE'])
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}]

# %%
grid_search_knn_z.evaluate(data)
# Out:
# ------------
# Parameters combination 1 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7154
# Mean RMSE: 0.9375
# ------------
# ------------
# Parameters combination 2 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7020
# Mean RMSE: 0.9174
# ------------
# ------------
# Parameters combination 3 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6981
# Mean RMSE: 0.9133
# ------------
# ------------
# Parameters combination 4 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7169
# Mean RMSE: 0.9570
# ------------
# ------------
# Parameters combination 5 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7123
# Mean RMSE: 0.9500
# ------------
# ------------
# Parameters combination 6 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7128
# Mean RMSE: 0.9506
# ------------
# ------------
# Parameters combination 7 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6900
# Mean RMSE: 0.9366
# ------------
# ------------
# Parameters combination 8 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6789
# Mean RMSE: 0.9180
# ------------
# ------------
# Parameters combination 9 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6748
# Mean RMSE: 0.9129
# ------------
# ------------
# Parameters combination 10 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7060
# Mean RMSE: 0.9546
# ------------
# ------------
# Parameters combination 11 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7043
# Mean RMSE: 0.9503
# ------------
# ------------
# Parameters combination 12 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7045
# Mean RMSE: 0.9501
# ------------
# ------------
# Parameters combination 13 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6909
# Mean RMSE: 0.9136
# ------------
# ------------
# Parameters combination 14 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6806
# Mean RMSE: 0.8979
# ------------
# ------------
# Parameters combination 15 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6794
# Mean RMSE: 0.8961
# ------------
# ------------
# Parameters combination 16 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7154
# Mean RMSE: 0.9573
# ------------
# ------------
# Parameters combination 17 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7120
# Mean RMSE: 0.9522
# ------------
# ------------
# Parameters combination 18 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7117
# Mean RMSE: 0.9518
# ------------

# %%
results_knn_z = pd.DataFrame.from_dict(grid_search_knn_z.cv_results)
results_knn_z
# Out:
#          MAE      RMSE   k  \
# 0   0.715423  0.937455  10
# 1   0.701981  0.917424  30
# 2   0.698123  0.913268  50
# 3   0.716903  0.957006  10
# 4   0.712304  0.950014  30
# 5   0.712783  0.950634  50
# 6   0.689984  0.936597  10
# 7   0.678860  0.918028  30
# 8   0.674817  0.912916  50
# 9   0.706012  0.954564  10
# 10  0.704326  0.950328  30
# 11  0.704468  0.950066  50
# 12  0.690939  0.913630  10
# 13  0.680639  0.897922  30
# 14  0.679402  0.896092  50
# 15  0.715407  0.957277  10
# 16  0.711956  0.952226  30
# 17  0.711678  0.951810  50
#
#                                                                                                 params  \
# 0                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# 1                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}
# 2                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# 3                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# 4                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}
# 5                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# 6            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 7            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 8            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# 9            {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 10           {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 11           {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# 12  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# 13  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# 14  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# 15  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# 16  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# 17  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
#
#                                                scores  \
# 0   {u'MAE': 0.715422525348, u'RMSE': 0.937455189091}
# 1    {u'MAE': 0.701981425043, u'RMSE': 0.91742419526}
# 2   {u'MAE': 0.698122850452, u'RMSE': 0.913268385227}
# 3   {u'MAE': 0.716903213679, u'RMSE': 0.957005667849}
# 4   {u'MAE': 0.712304021592, u'RMSE': 0.950013668519}
# 5   {u'MAE': 0.712783070101, u'RMSE': 0.950633551959}
# 6   {u'MAE': 0.689984053931, u'RMSE': 0.936597199821}
# 7   {u'MAE': 0.678859666337, u'RMSE': 0.918027790773}
# 8   {u'MAE': 0.674817359406, u'RMSE': 0.912916240877}
# 9   {u'MAE': 0.706011979267, u'RMSE': 0.954563649511}
# 10  {u'MAE': 0.704325963761, u'RMSE': 0.950327539021}
# 11  {u'MAE': 0.704468490559, u'RMSE': 0.950065785282}
# 12  {u'MAE': 0.690938788947, u'RMSE': 0.913629743932}
# 13  {u'MAE': 0.680638747165, u'RMSE': 0.897922086656}
# 14  {u'MAE': 0.679402436822, u'RMSE': 0.896092094192}
# 15  {u'MAE': 0.715406652283, u'RMSE': 0.957277300684}
# 16  {u'MAE': 0.711956470537, u'RMSE': 0.952225986816}
# 17    {u'MAE': 0.7116775207, u'RMSE': 0.951810156598}
#
#                                                                sim_options
# 0                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 1                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 2                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 3                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 4                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 5                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 6            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 7            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 8            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 9            {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 10           {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 11           {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 12  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 13  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 14  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 15  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}
# 16  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}
# 17  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}

# %%
algo = surprise.prediction_algorithms.knns.KNNWithMeans
param_grid = {'k': [10, 30, 50], 'sim_options': {'name': ['msd', 'pearson', 'pearson_baseline'], 'min_support': [1, 5], 'user_based': [True]}}
grid_search_knn_mean = surprise.GridSearch(algo, param_grid, measures=['MAE', 'RMSE'])
# Out:
# [{u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}, {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}]

# %%
grid_search_knn_mean.evaluate(data)
# Out:
# ------------
# Parameters combination 1 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7109
# Mean RMSE: 0.9302
# ------------
# ------------
# Parameters combination 2 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6980
# Mean RMSE: 0.9122
# ------------
# ------------
# Parameters combination 3 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6943
# Mean RMSE: 0.9082
# ------------
# ------------
# Parameters combination 4 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7177
# Mean RMSE: 0.9528
# ------------
# ------------
# Parameters combination 5 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7139
# Mean RMSE: 0.9482
# ------------
# ------------
# Parameters combination 6 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7141
# Mean RMSE: 0.9488
# ------------
# ------------
# Parameters combination 7 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6919
# Mean RMSE: 0.9360
# ------------
# ------------
# Parameters combination 8 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6784
# Mean RMSE: 0.9168
# ------------
# ------------
# Parameters combination 9 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6742
# Mean RMSE: 0.9121
# ------------
# ------------
# Parameters combination 10 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7111
# Mean RMSE: 0.9567
# ------------
# ------------
# Parameters combination 11 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7078
# Mean RMSE: 0.9515
# ------------
# ------------
# Parameters combination 12 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7078
# Mean RMSE: 0.9512
# ------------
# ------------
# Parameters combination 13 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6890
# Mean RMSE: 0.9101
# ------------
# ------------
# Parameters combination 14 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6781
# Mean RMSE: 0.8947
# ------------
# ------------
# Parameters combination 15 of 18
# params:  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.6767
# Mean RMSE: 0.8930
# ------------
# ------------
# Parameters combination 16 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7183
# Mean RMSE: 0.9572
# ------------
# ------------
# Parameters combination 17 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7144
# Mean RMSE: 0.9522
# ------------
# ------------
# Parameters combination 18 of 18
# params:  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean MAE : 0.7140
# Mean RMSE: 0.9518
# ------------

# %%
results_knn_mean = pd.DataFrame.from_dict(grid_search_knn_mean.cv_results)
results_knn_mean
# Out:
#          MAE      RMSE   k  \
# 0   0.710925  0.930242  10
# 1   0.698016  0.912158  30
# 2   0.694291  0.908162  50
# 3   0.717660  0.952762  10
# 4   0.713916  0.948218  30
# 5   0.714094  0.948755  50
# 6   0.691918  0.936010  10
# 7   0.678385  0.916840  30
# 8   0.674200  0.912068  50
# 9   0.711109  0.956709  10
# 10  0.707757  0.951549  30
# 11  0.707757  0.951243  50
# 12  0.688976  0.910065  10
# 13  0.678085  0.894678  30
# 14  0.676670  0.893010  50
# 15  0.718322  0.957231  10
# 16  0.714355  0.952230  30
# 17  0.714003  0.951846  50
#
#                                                                                                 params  \
# 0                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 10}
# 1                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 30}
# 2                {u'sim_options': {u'min_support': 1, u'name': u'msd', u'user_based': True}, u'k': 50}
# 3                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 10}
# 4                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 30}
# 5                {u'sim_options': {u'min_support': 5, u'name': u'msd', u'user_based': True}, u'k': 50}
# 6            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 7            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 8            {u'sim_options': {u'min_support': 1, u'name': u'pearson', u'user_based': True}, u'k': 50}
# 9            {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 10}
# 10           {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 30}
# 11           {u'sim_options': {u'min_support': 5, u'name': u'pearson', u'user_based': True}, u'k': 50}
# 12  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# 13  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# 14  {u'sim_options': {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
# 15  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 10}
# 16  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 30}
# 17  {u'sim_options': {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}, u'k': 50}
#
#                                                scores  \
# 0   {u'MAE': 0.710925176595, u'RMSE': 0.930241904917}
# 1    {u'MAE': 0.69801574464, u'RMSE': 0.912157977967}
# 2   {u'MAE': 0.694291443262, u'RMSE': 0.908162363368}
# 3   {u'MAE': 0.717660101501, u'RMSE': 0.952761705724}
# 4   {u'MAE': 0.713915633236, u'RMSE': 0.948217630033}
# 5   {u'MAE': 0.714093968606, u'RMSE': 0.948755016393}
# 6   {u'MAE': 0.691918178425, u'RMSE': 0.936009829352}
# 7   {u'MAE': 0.678384935198, u'RMSE': 0.916840231167}
# 8     {u'MAE': 0.67419951946, u'RMSE': 0.91206752072}
# 9   {u'MAE': 0.711109367272, u'RMSE': 0.956708962269}
# 10  {u'MAE': 0.707756512146, u'RMSE': 0.951548720086}
# 11  {u'MAE': 0.707757238187, u'RMSE': 0.951242846192}
# 12  {u'MAE': 0.688976447369, u'RMSE': 0.910065000566}
# 13   {u'MAE': 0.67808513993, u'RMSE': 0.894678250403}
# 14  {u'MAE': 0.676670050394, u'RMSE': 0.893010120865}
# 15  {u'MAE': 0.718322407817, u'RMSE': 0.957230719664}
# 16  {u'MAE': 0.714355180331, u'RMSE': 0.952230181652}
# 17  {u'MAE': 0.714003081785, u'RMSE': 0.951845602379}
#
#                                                                sim_options
# 0                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 1                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 2                {u'min_support': 1, u'name': u'msd', u'user_based': True}
# 3                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 4                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 5                {u'min_support': 5, u'name': u'msd', u'user_based': True}
# 6            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 7            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 8            {u'min_support': 1, u'name': u'pearson', u'user_based': True}
# 9            {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 10           {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 11           {u'min_support': 5, u'name': u'pearson', u'user_based': True}
# 12  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 13  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 14  {u'min_support': 1, u'name': u'pearson_baseline', u'user_based': True}
# 15  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}
# 16  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}
# 17  {u'min_support': 5, u'name': u'pearson_baseline', u'user_based': True}

# %%
def sample_users(df, min_rated):
    user_counts = pd.DataFrame(df['user_id'].value_counts())
    users = list(user_counts[user_counts['user_id'] >= min_rated].index)
    
    new_df = df[df.user_id.isin(users)]
    
    return new_df

# %%
sampled = sample_users(ratings, 100)

# %%
len(sampled.user_id.unique())
# Out:
# 37084

# %%
print('sparsity is {.8f}'.format(100.0*len(ratings.USER)/(len(ratings.USER.unique())*len(ratings.ITEM.unique()/len(ratings.USER)))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-d771d7b3f010> in <module>()
# ----> 1 print('sparsity is {.8f}'.format(100.0*len(ratings.USER)/(len(ratings.USER.unique())*len(ratings.ITEM.unique()/len(ratings.USER)))))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
sampled_ratings = ratings.sample(1000000, random_state=42)

# %%
print('{} users and {} items'.format(len(ratings.USER.unique()), len(ratings.ITEM.unique())))
# Out:
# 8026324 users and 2330066 items

# %%
item_counts = pd.DataFrame(ratings.ITEM.value_counts())

# %%
item_counts.ITEM.mean()
# Out:
# 9.659449560656222

# %%
item_counts.head()
# Out:
#              ITEM
# 0439023483  21398
# 030758836X  19867
# 0439023513  14114
# 0385537859  12973
# 0007444117  12629

# %%
item_counts.ITEM.between(100,5000,inclusive=True).sum()
# Out:
# 29243

# %%
#Same method as Mark's
def sample_books(df, n_samples, min_user_ratings, max_user_ratings, min_item_ratings, max_item_ratings):
    users_temp = pd.DataFrame(df['USER'].value_counts())
    users_list = list(users_temp[users_temp['USER'].between(min_user_ratings,max_user_ratings,inclusive=True)].index)
    
    items_temp = pd.DataFrame(df['ITEM'].value_counts())
    items_list = list(items_temp[items_temp['ITEM'].between(min_item_ratings,max_item_ratings,inclusive=True)].index)
    
    limited_df = df[df['USER'].isin(users_list) & df['ITEM'].isin(items_list)]
    
    sample = limited_df.sample(n_samples, random_state=42)
    return sample

# %%
sampled_df = sample_books(ratings, 100000, 30, 1000000, 75, 1000000)

# %%
len(sampled_df['ITEM'].unique())
# Out:
# 30603

# %%
sampled_df.head()
# Out:
#                     USER        ITEM  RATING   TIMESTAMP
# 17009092  A1KQ31B1998R79  1595547819     3.0  1361750400
# 5443680   A1M5ZT35YX6TIN  0441008534     5.0  1244246400
# 11941185  A1JLU5H1CCENWX  0985872586     5.0  1369353600
# 603401    A209J4NK7GR9S3  0061491896     3.0  1276387200
# 6793222   A103Q9172H9419  0578032147     4.0  1382745600

# %%
#Can first input the ratings dataframe, kind = 'USER', then run it again with the resulting df and kind = 'ITEM'
#returns the subset of users or items we have remaining, depending on kind and a new dataframe with only those remaining
def sample_kind(df, n_users, min_ratings, max_ratings, kind):
    counts = pd.DataFrame(df[kind].value_counts())
    counts = counts[counts[kind].between(min_ratings, max_ratings,inclusive=True)].reset_index()
    counts = counts.drop(kind, axis = 1)
#    subset = pd.DataFrame(counts.sample(n_users, random_state = 42))
    subset = pd.DataFrame(counts)
    new_df = subset.merge(right = df, how = 'left', left_on = 'index', right_on = kind, copy = False)
    new_df = new_df.drop('index', axis = 1)
    return subset, new_df

# %%
new_ratings = sample_kind(ratings, 100, 5, 100, 'ITEM')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-b38fa417e06f> in <module>()
# ----> 1 new_ratings.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
items, new_ratings = new_ratings[0], new_ratings[1]

# %%
new_ratings.shape
# Out:
# (11496998, 4)

# %%
len(new_ratings.USER.unique())
# Out:
# 5073473

# %%
users, new_ratings2 = sample_kind(new_ratings, 10000, 5, 100, 'USER')

# %%
new_ratings2.shape
# Out:
# (3873416, 4)

# %%
#returns the new dataframe with range restrictions before sampling, the remaining items, and the remaining users
def sample_merge(df, min_ratings, max_ratings, min_times_rated, max_times_rated):
    user_counts = pd.DataFrame(df['USER'].value_counts())
    user_counts = user_counts[user_counts['USER'].between(min_ratings, max_ratings, inclusive=True)].reset_index()
    # might have to delete next line
    user_counts = pd.DataFrame(user_counts.drop('USER', axis = 1))
    print(user_counts.isnull().sum())
    
    item_counts = pd.DataFrame(df['ITEM'].value_counts())
    item_counts = item_counts[item_counts['ITEM'].between(min_times_rated, max_times_rated, inclusive=True)].reset_index()
    # might have to delete next line
    item_counts = pd.DataFrame(item_counts.drop('ITEM', axis = 1))
    print(item_counts.isnull().sum())
    
    df2 = user_counts.merge(right = df, how = 'left', left_on = 'index', right_on = 'USER')
    df2.drop('index', axis = 1, inplace = True)
    df3 = item_counts.merge(right = df2, how = 'left', left_on = 'index', right_on = 'ITEM')
    df3.drop('index', axis = 1, inplace = True)
    df3.dropna(axis=0, inplace=True)
    
    return df3, item_counts, user_counts
